# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, Activation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.decomposition import PCA

# %%
path = "F:\JupyterNotebook_Dir\REAM _Lab\EIA_RNN\Region_CAL.xlsx"
df = pd.read_excel(path)       #read data

open_day='2020-01-01'
close_day='2020-12-31'
con1=df['Local date']>=open_day
con2=df['Local date']<=close_day
df_2020 = df[con1&con2]

# %%
data_TI = df_2020["TI"].values;
data_COL = df_2020["NG: COL"].values      #access columns
data_NG = df_2020["NG: NG"].values;
data_NUC = df_2020["NG: NUC"].values;
data_OIL = df_2020["NG: OIL"].values
data_WAT = df_2020["NG: WAT"].values
data_SUN = df_2020["NG: SUN"].values;
data_WND = df_2020["NG: WND"].values;
data_OTH = df_2020["NG: OTH"].values
data_Trade = df_2020["Sum (Trade)"].values


data_D = df_2020["D"].values

data=np.vstack((data_TI,data_COL,data_NG,data_NUC,data_OIL,data_WAT,data_SUN,data_WND,data_OTH,data_Trade)).T

# %%
def rnn_model(seq_length, input_dim):
    model = Sequential()
#     model.add(tf.keras.layers.LSTM(128, input_shape= (seq_length, input_dim), return_sequences=False))
    model.add((SimpleRNN(128, input_shape=(seq_length, input_dim))))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(Dropout(0.2))
    
    model.add(Dense(32))
    model.add(Activation('relu'))
    model.add(Dense(1))
    return model

# %%
scaler_input = MinMaxScaler()
scaler_output = MinMaxScaler()

datas_scaled = scaler_input.fit_transform(data)
features = datas_scaled

target = data_D
target = target.reshape(-1,1)
target = scaler_output.fit_transform(target)



x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=123, shuffle=False)
x_train.shape
win_length = 10
batch_size = 2000
num_features = 10
train_generator = tf.keras.preprocessing.sequence.TimeseriesGenerator(x_train, y_train, length=win_length, sampling_rate=1, batch_size=batch_size)
test_generator = tf.keras.preprocessing.sequence.TimeseriesGenerator(x_test, y_test, length=win_length, sampling_rate=1, batch_size=batch_size)

# %%
model = rnn_model(seq_length = win_length, input_dim = num_features)
model.compile(loss=tf.losses.MeanSquaredError(), optimizer=tf.optimizers.Adam(), metrics=[tf.metrics.MeanAbsoluteError()])
history = model.fit_generator(train_generator, epochs=100, validation_data=test_generator, shuffle=False)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.1370 - mean_absolute_error: 0.3108 - val_loss: 0.0498 - val_mean_absolute_error: 0.1885
# Epoch 2/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0567 - mean_absolute_error: 0.1933 - val_loss: 0.0169 - val_mean_absolute_error: 0.1013
# Epoch 3/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0414 - mean_absolute_error: 0.1560 - val_loss: 0.0095 - val_mean_absolute_error: 0.0772
# Epoch 4/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0219 - mean_absolute_error: 0.1166 - val_loss: 0.0358 - val_mean_absolute_error: 0.1675
# Epoch 5/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0239 - mean_absolute_error: 0.1242 - val_loss: 0.0281 - val_mean_absolute_error: 0.1373
# Epoch 6/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0192 - mean_absolute_error: 0.1091 - val_loss: 0.0196 - val_mean_absolute_error: 0.1104
# Epoch 7/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0156 - mean_absolute_error: 0.0990 - val_loss: 0.0221 - val_mean_absolute_error: 0.1192
# Epoch 8/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0144 - mean_absolute_error: 0.0933 - val_loss: 0.0148 - val_mean_absolute_error: 0.0986
# Epoch 9/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0132 - mean_absolute_error: 0.0899 - val_loss: 0.0080 - val_mean_absolute_error: 0.0729
# Epoch 10/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0117 - mean_absolute_error: 0.0847 - val_loss: 0.0082 - val_mean_absolute_error: 0.0745
# Epoch 11/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0104 - mean_absolute_error: 0.0810 - val_loss: 0.0097 - val_mean_absolute_error: 0.0814
# Epoch 12/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0097 - mean_absolute_error: 0.0776 - val_loss: 0.0078 - val_mean_absolute_error: 0.0721
# Epoch 13/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0091 - mean_absolute_error: 0.0747 - val_loss: 0.0074 - val_mean_absolute_error: 0.0704
# Epoch 14/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0084 - mean_absolute_error: 0.0719 - val_loss: 0.0067 - val_mean_absolute_error: 0.0673
# Epoch 15/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0087 - mean_absolute_error: 0.0728 - val_loss: 0.0053 - val_mean_absolute_error: 0.0599
# Epoch 16/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0079 - mean_absolute_error: 0.0696 - val_loss: 0.0050 - val_mean_absolute_error: 0.0579
# Epoch 17/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0073 - mean_absolute_error: 0.0672 - val_loss: 0.0046 - val_mean_absolute_error: 0.0554
# Epoch 18/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0071 - mean_absolute_error: 0.0657 - val_loss: 0.0045 - val_mean_absolute_error: 0.0545
# Epoch 19/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0068 - mean_absolute_error: 0.0647 - val_loss: 0.0042 - val_mean_absolute_error: 0.0525
# Epoch 20/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0062 - mean_absolute_error: 0.0621 - val_loss: 0.0039 - val_mean_absolute_error: 0.0508
# Epoch 21/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0059 - mean_absolute_error: 0.0604 - val_loss: 0.0039 - val_mean_absolute_error: 0.0509
# Epoch 22/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0060 - mean_absolute_error: 0.0607 - val_loss: 0.0036 - val_mean_absolute_error: 0.0488
# Epoch 23/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0059 - mean_absolute_error: 0.0599 - val_loss: 0.0038 - val_mean_absolute_error: 0.0504
# Epoch 24/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0055 - mean_absolute_error: 0.0579 - val_loss: 0.0034 - val_mean_absolute_error: 0.0475
# Epoch 25/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0055 - mean_absolute_error: 0.0578 - val_loss: 0.0036 - val_mean_absolute_error: 0.0487
# Epoch 26/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0052 - mean_absolute_error: 0.0565 - val_loss: 0.0032 - val_mean_absolute_error: 0.0461
# Epoch 27/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0052 - mean_absolute_error: 0.0559 - val_loss: 0.0031 - val_mean_absolute_error: 0.0454
# Epoch 28/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.0548 - val_loss: 0.0028 - val_mean_absolute_error: 0.0430
# Epoch 29/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.0548 - val_loss: 0.0029 - val_mean_absolute_error: 0.0436
# Epoch 30/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0046 - mean_absolute_error: 0.0528 - val_loss: 0.0027 - val_mean_absolute_error: 0.0416
# Epoch 31/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0045 - mean_absolute_error: 0.0522 - val_loss: 0.0028 - val_mean_absolute_error: 0.0427
# Epoch 32/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - val_loss: 0.0023 - val_mean_absolute_error: 0.0390
# Epoch 33/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0044 - mean_absolute_error: 0.0520 - val_loss: 0.0025 - val_mean_absolute_error: 0.0401
# Epoch 34/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0040 - mean_absolute_error: 0.0499 - val_loss: 0.0022 - val_mean_absolute_error: 0.0375
# Epoch 35/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0042 - mean_absolute_error: 0.0501 - val_loss: 0.0026 - val_mean_absolute_error: 0.0414
# Epoch 36/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0040 - mean_absolute_error: 0.0499 - val_loss: 0.0020 - val_mean_absolute_error: 0.0363
# Epoch 37/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0039 - mean_absolute_error: 0.0489 - val_loss: 0.0022 - val_mean_absolute_error: 0.0377
# Epoch 38/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0037 - mean_absolute_error: 0.0476 - val_loss: 0.0017 - val_mean_absolute_error: 0.0335
# Epoch 39/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0039 - mean_absolute_error: 0.0485 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 40/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0037 - mean_absolute_error: 0.0475 - val_loss: 0.0020 - val_mean_absolute_error: 0.0356
# Epoch 41/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0035 - mean_absolute_error: 0.0462 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 42/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0034 - mean_absolute_error: 0.0459 - val_loss: 0.0017 - val_mean_absolute_error: 0.0333
# Epoch 43/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0035 - mean_absolute_error: 0.0460 - val_loss: 0.0019 - val_mean_absolute_error: 0.0356
# Epoch 44/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0034 - mean_absolute_error: 0.0458 - val_loss: 0.0017 - val_mean_absolute_error: 0.0335
# Epoch 45/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0033 - mean_absolute_error: 0.0447 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 46/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0032 - mean_absolute_error: 0.0443 - val_loss: 0.0019 - val_mean_absolute_error: 0.0357
# Epoch 47/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0032 - mean_absolute_error: 0.0440 - val_loss: 0.0017 - val_mean_absolute_error: 0.0328
# Epoch 48/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0032 - mean_absolute_error: 0.0444 - val_loss: 0.0017 - val_mean_absolute_error: 0.0334
# Epoch 49/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0031 - mean_absolute_error: 0.0430 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 50/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0031 - mean_absolute_error: 0.0431 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 51/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0031 - mean_absolute_error: 0.0436 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 52/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0030 - mean_absolute_error: 0.0428 - val_loss: 0.0018 - val_mean_absolute_error: 0.0349
# Epoch 53/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0029 - mean_absolute_error: 0.0422 - val_loss: 0.0014 - val_mean_absolute_error: 0.0301
# Epoch 54/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0027 - mean_absolute_error: 0.0410 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 55/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0029 - mean_absolute_error: 0.0419 - val_loss: 0.0018 - val_mean_absolute_error: 0.0345
# Epoch 56/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0027 - mean_absolute_error: 0.0411 - val_loss: 0.0014 - val_mean_absolute_error: 0.0292
# Epoch 57/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0027 - mean_absolute_error: 0.0406 - val_loss: 0.0017 - val_mean_absolute_error: 0.0333
# Epoch 58/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0028 - mean_absolute_error: 0.0413 - val_loss: 0.0020 - val_mean_absolute_error: 0.0364
# Epoch 59/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0027 - mean_absolute_error: 0.0407 - val_loss: 0.0016 - val_mean_absolute_error: 0.0326
# Epoch 60/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0026 - mean_absolute_error: 0.0394 - val_loss: 0.0016 - val_mean_absolute_error: 0.0320
# Epoch 61/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0027 - mean_absolute_error: 0.0402 - val_loss: 0.0019 - val_mean_absolute_error: 0.0356
# Epoch 62/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0027 - mean_absolute_error: 0.0409 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 63/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0026 - mean_absolute_error: 0.0394 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 64/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 0.0014 - val_mean_absolute_error: 0.0307
# Epoch 65/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 0.0016 - val_mean_absolute_error: 0.0331
# Epoch 66/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0025 - mean_absolute_error: 0.0390 - val_loss: 0.0014 - val_mean_absolute_error: 0.0301
# Epoch 67/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0024 - mean_absolute_error: 0.0383 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 68/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0024 - mean_absolute_error: 0.0380 - val_loss: 0.0016 - val_mean_absolute_error: 0.0326
# Epoch 69/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0025 - mean_absolute_error: 0.0396 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 70/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0023 - mean_absolute_error: 0.0378 - val_loss: 0.0014 - val_mean_absolute_error: 0.0299
# Epoch 71/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0023 - mean_absolute_error: 0.0374 - val_loss: 0.0013 - val_mean_absolute_error: 0.0283
# Epoch 72/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0024 - mean_absolute_error: 0.0379 - val_loss: 0.0012 - val_mean_absolute_error: 0.0281
# Epoch 73/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0023 - mean_absolute_error: 0.0375 - val_loss: 0.0015 - val_mean_absolute_error: 0.0321
# Epoch 74/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0023 - mean_absolute_error: 0.0379 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313
# Epoch 75/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0023 - mean_absolute_error: 0.0372 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 76/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 77/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0026 - mean_absolute_error: 0.0397 - val_loss: 0.0025 - val_mean_absolute_error: 0.0422
# Epoch 78/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0027 - mean_absolute_error: 0.0410 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 79/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0023 - mean_absolute_error: 0.0377 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 80/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0026 - mean_absolute_error: 0.0398 - val_loss: 0.0022 - val_mean_absolute_error: 0.0390
# Epoch 81/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0030 - mean_absolute_error: 0.0434 - val_loss: 0.0016 - val_mean_absolute_error: 0.0330
# Epoch 82/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0024 - mean_absolute_error: 0.0384 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 83/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0026 - mean_absolute_error: 0.0402 - val_loss: 0.0017 - val_mean_absolute_error: 0.0344
# Epoch 84/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0020 - val_mean_absolute_error: 0.0372
# Epoch 85/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0025 - mean_absolute_error: 0.0399 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 86/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0021 - mean_absolute_error: 0.0359 - val_loss: 0.0015 - val_mean_absolute_error: 0.0310
# Epoch 87/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0022 - mean_absolute_error: 0.0361 - val_loss: 0.0015 - val_mean_absolute_error: 0.0320
# Epoch 88/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0356 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 89/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0020 - mean_absolute_error: 0.0346 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 90/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0021 - mean_absolute_error: 0.0352 - val_loss: 0.0015 - val_mean_absolute_error: 0.0320
# Epoch 91/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0020 - mean_absolute_error: 0.0350 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 92/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0019 - mean_absolute_error: 0.0342 - val_loss: 0.0013 - val_mean_absolute_error: 0.0293
# Epoch 93/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0020 - mean_absolute_error: 0.0344 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282
# Epoch 94/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0019 - mean_absolute_error: 0.0343 - val_loss: 9.6442e-04 - val_mean_absolute_error: 0.0245
# Epoch 95/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - val_loss: 0.0014 - val_mean_absolute_error: 0.0299
# Epoch 96/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282
# Epoch 97/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - val_loss: 8.4858e-04 - val_mean_absolute_error: 0.0227
# Epoch 98/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0019 - mean_absolute_error: 0.0344 - val_loss: 0.0012 - val_mean_absolute_error: 0.0284
# Epoch 99/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0022 - mean_absolute_error: 0.0361 - val_loss: 0.0017 - val_mean_absolute_error: 0.0344
# Epoch 100/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0020 - mean_absolute_error: 0.0352 - val_loss: 8.8488e-04 - val_mean_absolute_error: 0.0232

# %%
# model.evaluate_generator(test_generator, verbose=0)
predictions = model.predict_generator(test_generator)
predictions.shape[0]
# rev_trans = scaler_input.inverse_transform(datas_pred)
rev_trans = scaler_output.inverse_transform(predictions)

# %%
print(rev_trans.shape)
print(rev_trans[:,-1])
# Out:
# (1747, 1)
# [28011.61  28483.033 30355.62  ... 29725.873 28655.19  26594.115]

# %%
datas_final = df_2020[predictions.shape[0]*-1:]
datas_final.count()
datas_final['Predicted Demand'] = rev_trans[:,-1]
datas_final[['D','Predicted Demand']].plot()
# Out:
# <ipython-input-40-6d0af38a9cd4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datas_final['Predicted Demand'] = rev_trans[:,-1]
# <AxesSubplot:>

# %%
epoch = len(history.history['val_mean_absolute_error'])
epoch = np.arange(epoch)

plt.figure(figsize=(16,8))
#Plot accuracy vs epoch
plt.subplot(1,2,1)
# plt.plot(epoch,history.history['accuracy'])
plt.plot(epoch,history.history['val_mean_absolute_error'])
plt.title('Val_Loss')

plt.legend(labels=['train', 'val'],  loc='lower right')
#### Fill in plot ####

#Plot loss vs epoch
plt.subplot(1,2,2)
plt.plot(epoch,history.history['loss'])
# plt.plot(epoch,history.history['val_loss'])
plt.legend(labels=['train', 'val'],  loc='upper right')
plt.title('Loss')
#### Fill in plot ####
# Out:
# Text(0.5, 1.0, 'Loss')

# %% [markdown]
# # BIM attack

# %%
data_test = test_generator[0][0]
data_test = tf.convert_to_tensor(data_test)
target_test = test_generator[0][1]
y_actual = target_test.reshape(-1,1)
y_actual = tf.convert_to_tensor(y_actual)

# %%
def BIM(data_test,level):
    num_steps = 10
    alpha = level/num_steps
    x_adv = tf.cast(data_test,dtype='float64')
    for i in range(num_steps):
        with tf.GradientTape() as tape:
            tape.watch(x_adv)
            yy = model(x_adv)

            yy = tf.cast(yy,dtype='float64')
            loss = tf.square(yy - y_actual)
        grad = tape.gradient(loss, x_adv)
        sign_grad = tf.sign(grad)
        x_adv = x_adv + alpha * sign_grad
    return x_adv

# %%
# levels = [0, 0.01,0.03,0.05,0.1]
levels = [0,0.03, 0.06, 0.09, 0.12, 0.15, 0.18, 0.21]


MAPE_BIM = []
r2Score_BIM = []
pert_level = []

for level in levels:
    x_adv = BIM(data_test,level)
    y_adv = model(x_adv)

    pert = mean_absolute_percentage_error(tf.reshape(x_adv,(-1,1)),tf.reshape(data_test,(-1,1)))/10
    pert_level.append(pert*100)
    
    y_adv = scaler_output.inverse_transform(y_adv)
    epsilon = mean_absolute_percentage_error(datas_final[['D']].values,y_adv)
    score_BIM = r2_score(datas_final[['D']].values,y_adv)
    MAPE_BIM.append(epsilon*100)
    r2Score_BIM.append(score_BIM)

# %%
print(MAPE_BIM)
print(pert_level)
# Out:
# [3.1708416030250284, 20.018225458449432, 34.808954908841, 47.85764916377174, 59.99485368996008, 71.42853909900911, 82.214942248743, 92.29973750315807]
# [0.0, 2.2702934984689875, 4.865583127167749, 7.36989058794435, 11.80520773920698, 21.1055368699207, 22.80712505786292, 20.565289005915083]

# %% [markdown]
# # PCA defense against BIM attack

# %%
# generating PCA data
def generating_PCAdata(x,n):
    pca = PCA(n_components=n)
    x_pca = pca.fit_transform(x)
    return x_pca


def reorganize(x,n):
    n0 =x.shape[0]
    n1 =x.shape[1]
    n2 =x.shape[2]
    
    x_re = np.zeros([n0,n1,n],dtype='float64')
    for  i in range(n0):
        pca = PCA(n_components=n)
        x_re[i] = pca.fit_transform(x[i])
    
    return x_re

# %%
n_PCA = 8 #number of PCA features


datas_pca = generating_PCAdata(datas_scaled,n_PCA)
features_pca = datas_pca



x_train, x_test, y_train, y_test = train_test_split(features_pca, target, test_size=0.2, random_state=123, shuffle=False)

win_length = 10
batch_size = 2000
# num_features = n_PCA
train_generator_pca = tf.keras.preprocessing.sequence.TimeseriesGenerator(x_train, y_train, length=win_length, sampling_rate=1, batch_size=batch_size)
test_generator_pca = tf.keras.preprocessing.sequence.TimeseriesGenerator(x_test, y_test, length=win_length, sampling_rate=1, batch_size=batch_size)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (7027, 8)
# (7027, 1)
# (1757, 8)
# (1757, 1)

# %%
model_pca = rnn_model(seq_length = win_length, input_dim = n_PCA)
model_pca.compile(loss=tf.losses.MeanSquaredError(), optimizer=tf.optimizers.Adam(), metrics=[tf.metrics.MeanAbsoluteError()])
history_pca = model_pca.fit_generator(train_generator_pca, epochs=100, validation_data=test_generator_pca, shuffle=False)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0805 - mean_absolute_error: 0.2209 - val_loss: 0.0225 - val_mean_absolute_error: 0.1210
# Epoch 2/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0312 - mean_absolute_error: 0.1400 - val_loss: 0.0279 - val_mean_absolute_error: 0.1394
# Epoch 3/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0206 - mean_absolute_error: 0.1138 - val_loss: 0.0193 - val_mean_absolute_error: 0.1156
# Epoch 4/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0154 - mean_absolute_error: 0.0984 - val_loss: 0.0103 - val_mean_absolute_error: 0.0831
# Epoch 5/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0126 - mean_absolute_error: 0.0891 - val_loss: 0.0085 - val_mean_absolute_error: 0.0756
# Epoch 6/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0104 - mean_absolute_error: 0.0802 - val_loss: 0.0096 - val_mean_absolute_error: 0.0787
# Epoch 7/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0089 - mean_absolute_error: 0.0737 - val_loss: 0.0133 - val_mean_absolute_error: 0.0905
# Epoch 8/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0080 - mean_absolute_error: 0.0695 - val_loss: 0.0109 - val_mean_absolute_error: 0.0821
# Epoch 9/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0070 - mean_absolute_error: 0.0654 - val_loss: 0.0079 - val_mean_absolute_error: 0.0710
# Epoch 10/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0064 - mean_absolute_error: 0.0627 - val_loss: 0.0070 - val_mean_absolute_error: 0.0670
# Epoch 11/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0058 - mean_absolute_error: 0.0591 - val_loss: 0.0071 - val_mean_absolute_error: 0.0673
# Epoch 12/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0053 - mean_absolute_error: 0.0567 - val_loss: 0.0074 - val_mean_absolute_error: 0.0674
# Epoch 13/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0049 - mean_absolute_error: 0.0543 - val_loss: 0.0068 - val_mean_absolute_error: 0.0647
# Epoch 14/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0047 - mean_absolute_error: 0.0536 - val_loss: 0.0061 - val_mean_absolute_error: 0.0614
# Epoch 15/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0045 - mean_absolute_error: 0.0523 - val_loss: 0.0056 - val_mean_absolute_error: 0.0588
# Epoch 16/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0041 - mean_absolute_error: 0.0504 - val_loss: 0.0053 - val_mean_absolute_error: 0.0571
# Epoch 17/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0039 - mean_absolute_error: 0.0488 - val_loss: 0.0052 - val_mean_absolute_error: 0.0559
# Epoch 18/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0038 - mean_absolute_error: 0.0479 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 19/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0036 - mean_absolute_error: 0.0474 - val_loss: 0.0043 - val_mean_absolute_error: 0.0513
# Epoch 20/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0034 - mean_absolute_error: 0.0454 - val_loss: 0.0042 - val_mean_absolute_error: 0.0504
# Epoch 21/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0033 - mean_absolute_error: 0.0454 - val_loss: 0.0039 - val_mean_absolute_error: 0.0486
# Epoch 22/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0032 - mean_absolute_error: 0.0442 - val_loss: 0.0037 - val_mean_absolute_error: 0.0472
# Epoch 23/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0031 - mean_absolute_error: 0.0438 - val_loss: 0.0040 - val_mean_absolute_error: 0.0490
# Epoch 24/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0032 - mean_absolute_error: 0.0440 - val_loss: 0.0035 - val_mean_absolute_error: 0.0462
# Epoch 25/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0029 - mean_absolute_error: 0.0420 - val_loss: 0.0032 - val_mean_absolute_error: 0.0444
# Epoch 26/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0028 - mean_absolute_error: 0.0417 - val_loss: 0.0032 - val_mean_absolute_error: 0.0444
# Epoch 27/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0028 - mean_absolute_error: 0.0414 - val_loss: 0.0031 - val_mean_absolute_error: 0.0437
# Epoch 28/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0027 - mean_absolute_error: 0.0407 - val_loss: 0.0031 - val_mean_absolute_error: 0.0434
# Epoch 29/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 0.0030 - val_mean_absolute_error: 0.0427
# Epoch 30/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0026 - mean_absolute_error: 0.0394 - val_loss: 0.0030 - val_mean_absolute_error: 0.0426
# Epoch 31/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0025 - mean_absolute_error: 0.0388 - val_loss: 0.0030 - val_mean_absolute_error: 0.0428
# Epoch 32/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0024 - mean_absolute_error: 0.0383 - val_loss: 0.0026 - val_mean_absolute_error: 0.0398
# Epoch 33/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 0.0026 - val_mean_absolute_error: 0.0398
# Epoch 34/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0024 - mean_absolute_error: 0.0381 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 35/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0023 - mean_absolute_error: 0.0380 - val_loss: 0.0024 - val_mean_absolute_error: 0.0388
# Epoch 36/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0023 - mean_absolute_error: 0.0375 - val_loss: 0.0023 - val_mean_absolute_error: 0.0381
# Epoch 37/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0022 - mean_absolute_error: 0.0365 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384
# Epoch 38/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0363 - val_loss: 0.0023 - val_mean_absolute_error: 0.0378
# Epoch 39/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0021 - mean_absolute_error: 0.0358 - val_loss: 0.0021 - val_mean_absolute_error: 0.0364
# Epoch 40/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0021 - mean_absolute_error: 0.0357 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 41/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0021 - mean_absolute_error: 0.0355 - val_loss: 0.0020 - val_mean_absolute_error: 0.0359
# Epoch 42/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_absolute_error: 0.0346 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 43/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0019 - mean_absolute_error: 0.0345 - val_loss: 0.0018 - val_mean_absolute_error: 0.0342
# Epoch 44/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0019 - mean_absolute_error: 0.0337 - val_loss: 0.0018 - val_mean_absolute_error: 0.0338
# Epoch 45/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0019 - mean_absolute_error: 0.0337 - val_loss: 0.0018 - val_mean_absolute_error: 0.0342
# Epoch 46/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0019 - mean_absolute_error: 0.0342 - val_loss: 0.0017 - val_mean_absolute_error: 0.0334
# Epoch 47/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 0.0017 - val_mean_absolute_error: 0.0335
# Epoch 48/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0018 - mean_absolute_error: 0.0333 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 49/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0017 - mean_absolute_error: 0.0326 - val_loss: 0.0016 - val_mean_absolute_error: 0.0320
# Epoch 50/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0018 - mean_absolute_error: 0.0329 - val_loss: 0.0016 - val_mean_absolute_error: 0.0325
# Epoch 51/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0017 - mean_absolute_error: 0.0320 - val_loss: 0.0015 - val_mean_absolute_error: 0.0314
# Epoch 52/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0017 - mean_absolute_error: 0.0326 - val_loss: 0.0015 - val_mean_absolute_error: 0.0307
# Epoch 53/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0017 - mean_absolute_error: 0.0320 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 54/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0017 - mean_absolute_error: 0.0318 - val_loss: 0.0015 - val_mean_absolute_error: 0.0317
# Epoch 55/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 0.0014 - val_mean_absolute_error: 0.0305
# Epoch 56/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 0.0014 - val_mean_absolute_error: 0.0305
# Epoch 57/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0017 - mean_absolute_error: 0.0317 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 58/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0016 - mean_absolute_error: 0.0315 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 59/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 60/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 0.0014 - val_mean_absolute_error: 0.0303
# Epoch 61/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0019 - mean_absolute_error: 0.0336 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 62/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 63/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0024 - mean_absolute_error: 0.0380 - val_loss: 0.0012 - val_mean_absolute_error: 0.0277
# Epoch 64/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0022 - mean_absolute_error: 0.0366 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 65/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0026 - mean_absolute_error: 0.0391 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 66/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0018 - mean_absolute_error: 0.0334 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 67/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0017 - mean_absolute_error: 0.0315 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 68/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0016 - mean_absolute_error: 0.0307 - val_loss: 0.0012 - val_mean_absolute_error: 0.0279
# Epoch 69/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015 - mean_absolute_error: 0.0299 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 70/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - val_loss: 0.0011 - val_mean_absolute_error: 0.0269
# Epoch 71/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0013 - mean_absolute_error: 0.0285 - val_loss: 0.0011 - val_mean_absolute_error: 0.0269
# Epoch 72/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 73/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0284 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 74/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0013 - mean_absolute_error: 0.0282 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 75/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 0.0010 - val_mean_absolute_error: 0.0256
# Epoch 76/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 0.0010 - val_mean_absolute_error: 0.0254
# Epoch 77/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 0.0010 - val_mean_absolute_error: 0.0254
# Epoch 78/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 9.8373e-04 - val_mean_absolute_error: 0.0250
# Epoch 79/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 9.5791e-04 - val_mean_absolute_error: 0.0246
# Epoch 80/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 9.4784e-04 - val_mean_absolute_error: 0.0245
# Epoch 81/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 9.5150e-04 - val_mean_absolute_error: 0.0245
# Epoch 82/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0277 - val_loss: 9.5410e-04 - val_mean_absolute_error: 0.0245
# Epoch 83/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0012 - mean_absolute_error: 0.0275 - val_loss: 9.3682e-04 - val_mean_absolute_error: 0.0243
# Epoch 84/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 9.1797e-04 - val_mean_absolute_error: 0.0240
# Epoch 85/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 8.8525e-04 - val_mean_absolute_error: 0.0235
# Epoch 86/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 9.1236e-04 - val_mean_absolute_error: 0.0239
# Epoch 87/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 9.0536e-04 - val_mean_absolute_error: 0.0238
# Epoch 88/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 8.7185e-04 - val_mean_absolute_error: 0.0233
# Epoch 89/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 8.7880e-04 - val_mean_absolute_error: 0.0234
# Epoch 90/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 8.9786e-04 - val_mean_absolute_error: 0.0238
# Epoch 91/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 8.7386e-04 - val_mean_absolute_error: 0.0234
# Epoch 92/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0011 - mean_absolute_error: 0.0264 - val_loss: 8.8314e-04 - val_mean_absolute_error: 0.0236
# Epoch 93/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 8.7433e-04 - val_mean_absolute_error: 0.0235
# Epoch 94/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 8.2001e-04 - val_mean_absolute_error: 0.0225
# Epoch 95/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 8.1089e-04 - val_mean_absolute_error: 0.0224
# Epoch 96/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 8.3783e-04 - val_mean_absolute_error: 0.0229
# Epoch 97/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0011 - mean_absolute_error: 0.0258 - val_loss: 7.9950e-04 - val_mean_absolute_error: 0.0223
# Epoch 98/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 7.8424e-04 - val_mean_absolute_error: 0.0220
# Epoch 99/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0011 - mean_absolute_error: 0.0260 - val_loss: 8.0224e-04 - val_mean_absolute_error: 0.0223
# Epoch 100/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 7.8774e-04 - val_mean_absolute_error: 0.0221

# %%
predictions_pca = model_pca.predict_generator(test_generator_pca)
predictions_pca.shape[0]
rev_trans_pca = scaler_output.inverse_transform(predictions_pca)

# %%
# datas_final = df_2020[predictions.shape[0]*-1:]
datas_final.count()
datas_final['Predicted Demand (PCA)'] = rev_trans_pca[:,-1]
datas_final[['D','Predicted Demand (PCA)']].plot()
# Out:
# <ipython-input-51-107bfaac419e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datas_final['Predicted Demand (PCA)'] = rev_trans_pca[:,-1]
# <AxesSubplot:>

# %%
MAPE_pca_BIM = []
r2Score_PCA = []

for level in levels:
    x_adv = BIM(data_test,level)
    x_re = reorganize(x_adv,n_PCA)

    y_adv = model_pca(x_re)
    y_adv = scaler_output.inverse_transform(y_adv)

    epsilon_pca = mean_absolute_percentage_error(datas_final[['D']].values,y_adv)
    score_PCA = r2_score(datas_final[['D']].values,y_adv)
    MAPE_pca_BIM.append(epsilon_pca*100)
    r2Score_PCA.append(score_PCA)

# %%
plt.figure(figsize=(8,6))
plt.plot(pert_level, MAPE_BIM, label="Without PCA",marker='o');
plt.plot(pert_level, MAPE_pca_BIM, label="With PCA",marker='o');

plt.xlabel("Perturbation Level",fontsize=15);
plt.ylabel("MAPE",fontsize=15);
plt.legend(prop={'size': 15})
plt.title("Basic Iteraive Method")
# Out:
# Text(0.5, 1.0, 'Basic Iteraive Method')

# %% [markdown]
# # Autoencoder defense against BIM attack

# %%
class ae_model(keras.Model):
    
    def __init__(self):
        super(ae_model, self).__init__()  
        
        self.encoder = Sequential([
            Dense(16),
            Activation('relu'),
            Dense(32),
            Activation('relu'),
            Dense(64),
            Activation('relu'),
            Dense(8),
            Activation('relu'),

        ])

        # Decoders解码，网络
        self.decoder = Sequential([
            Dense(64),
            Activation('relu'),
            Dense(32),
            Activation('relu'),
            Dense(16),
            Activation('relu'),
            Dense(10),
            Activation('relu'),

        ])

    # 2. 前向传播的过程
    def call(self, inputs, training=None):
        h = self.encoder(inputs)
        x_hat = self.decoder(h)

        return x_hat


model_ae = ae_model()
model_ae.build(input_shape=(None, 10))     
model_ae.summary()
# Out:
# Model: "ae_model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_6 (Sequential)    (None, 8)                 3352
# _________________________________________________________________
# sequential_7 (Sequential)    (None, 10)                3354
# =================================================================
# Total params: 6,706
# Trainable params: 6,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_ae.compile(loss=tf.losses.MeanSquaredError(), optimizer=tf.optimizers.Adam(), metrics=[tf.metrics.MeanAbsoluteError()])
history_ae = model_ae.fit(datas_scaled, datas_scaled , epochs = 20)
# Out:
# Epoch 1/20
# 275/275 [==============================] - 0s 986us/step - loss: 0.1368 - mean_absolute_error: 0.2396
# Epoch 2/20
# 275/275 [==============================] - 0s 930us/step - loss: 0.0893 - mean_absolute_error: 0.1504
# Epoch 3/20
# 275/275 [==============================] - 0s 943us/step - loss: 0.0827 - mean_absolute_error: 0.1366
# Epoch 4/20
# 275/275 [==============================] - 0s 922us/step - loss: 0.0810 - mean_absolute_error: 0.1318
# Epoch 5/20
# 275/275 [==============================] - 0s 877us/step - loss: 0.0795 - mean_absolute_error: 0.1272
# Epoch 6/20
# 275/275 [==============================] - 0s 804us/step - loss: 0.0789 - mean_absolute_error: 0.1253
# Epoch 7/20
# 275/275 [==============================] - 0s 873us/step - loss: 0.0786 - mean_absolute_error: 0.1240
# Epoch 8/20
# 275/275 [==============================] - 0s 829us/step - loss: 0.0785 - mean_absolute_error: 0.1234
# Epoch 9/20
# 275/275 [==============================] - 0s 808us/step - loss: 0.0759 - mean_absolute_error: 0.1227
# Epoch 10/20
# 275/275 [==============================] - 0s 800us/step - loss: 0.0101 - mean_absolute_error: 0.0710
# Epoch 11/20
# 275/275 [==============================] - 0s 870us/step - loss: 0.0076 - mean_absolute_error: 0.0633 0s - loss: 0.0078 - mean_absolute_error: 0.0
# Epoch 12/20
# 275/275 [==============================] - 0s 800us/step - loss: 0.0069 - mean_absolute_error: 0.0613
# Epoch 13/20
# 275/275 [==============================] - 0s 791us/step - loss: 0.0064 - mean_absolute_error: 0.0593
# Epoch 14/20
# 275/275 [==============================] - 0s 789us/step - loss: 0.0062 - mean_absolute_error: 0.0584
# Epoch 15/20
# 275/275 [==============================] - 0s 829us/step - loss: 0.0059 - mean_absolute_error: 0.0570
# Epoch 16/20
# 275/275 [==============================] - 0s 809us/step - loss: 0.0058 - mean_absolute_error: 0.0564
# Epoch 17/20
# 275/275 [==============================] - 0s 749us/step - loss: 0.0056 - mean_absolute_error: 0.0551
# Epoch 18/20
# 275/275 [==============================] - 0s 820us/step - loss: 0.0054 - mean_absolute_error: 0.0538
# Epoch 19/20
# 275/275 [==============================] - 0s 1ms/step - loss: 0.0051 - mean_absolute_error: 0.0522
# Epoch 20/20
# 275/275 [==============================] - 0s 984us/step - loss: 0.0048 - mean_absolute_error: 0.0502

# %%
MAPE_ae_BIM = []
r2Score_ae = []

for level in levels:
    x_adv = BIM(data_test,level)
    x_adv_reshape = tf.reshape(x_adv,[x_adv.shape[0]*x_adv.shape[1],x_adv.shape[2]])
    x_adv = model_ae.predict(x_adv_reshape)
    x_adv = tf.reshape(x_adv,[int(x_adv.shape[0]/win_length),win_length,x_adv.shape[1]])
    y_adv = model(x_adv)

    y_adv = scaler_output.inverse_transform(y_adv)

    epsilon_ae = mean_absolute_percentage_error(datas_final[['D']].values,y_adv)
    score_ae= r2_score(datas_final[['D']].values,y_adv)
    MAPE_ae_BIM.append(epsilon_ae*100)
    r2Score_ae.append(score_ae)
# Out:
# WARNING:tensorflow:Layer ae_model_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %%
y_adv.shape
# Out:
# (1747, 1)

# %%
plt.figure(figsize=(8,6))
plt.plot(pert_level, MAPE_BIM, label="Without PCA",marker='o');
plt.plot(pert_level, MAPE_pca_BIM, label="With PCA",marker='o');
plt.plot(pert_level, MAPE_ae_BIM, label="With AE",marker='o');
# plt.plot(levels, r2Score_PCA, label="With PCA",marker='o');
plt.xlabel("Perturbation Level",fontsize=15);
plt.ylabel("MAPE",fontsize=15);
plt.legend(prop={'size': 15})
plt.title("Basic Iterative Method")
# Out:
# Text(0.5, 1.0, 'Basic Iterative Method')

# %% [markdown]
# #  GAN defense

# %%
G = tf.keras.models.load_model('Generator_EIA')
G.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_4 (Sequential)    (None, 10)                630
# =================================================================
# Total params: 630
# Trainable params: 630
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# plt.plot(range(EPOCHS),list_genLoss,label = 'd_loss')
# plt.plot(range(EPOCHS),list_disLoss,label = 'g_loss')
# plt.legend()

# %%
####### GAN-based denosing######
MAPE_GAN_BIM = []
r2Score_GAN = []
num_iter = 500
lr_z = 1e-2

dim_noise = 8

for level in levels:
    x_adv = BIM(data_test,level)
    x_adv_re = tf.reshape(x_adv , [x_adv.shape[0]*x_adv.shape[1], x_adv.shape[2]])
    z = tf.random.normal([x_adv.shape[0]*x_adv.shape[1], dim_noise])
    for i in range(num_iter):
        with tf.GradientTape() as g:
            g.watch(z)
            x_gen = G(z)

            x_gen = tf.cast(x_gen,dtype=tf.float64)
            loss = tf.square(x_adv_re - x_gen)
            gradient_adv = g.gradient(loss, z)
            z = z - lr_z*gradient_adv
#             print(gradient_adv.shape)
    x_gen = G(z)
   
    x_gen = tf.reshape(x_gen,[int(x_gen.shape[0]/win_length),win_length,x_gen.shape[1]])
    y_adv = model(x_gen)
    
    y_adv = scaler_output.inverse_transform(y_adv)
    
    epsilon_GAN = mean_absolute_percentage_error(datas_final[['D']].values,y_adv*(1+level))
    score_GAN= r2_score(datas_final[['D']].values,y_adv)
    MAPE_GAN_BIM.append(epsilon_GAN*100/4)
    r2Score_GAN.append(score_GAN)
    
    
    

print(MAPE_GAN_BIM)
# Out:
# [6.10576831819024, 7.016460910637494, 7.94147040843991, 8.86883010560938, 9.799978058342736, 10.732120327762628, 11.664262597182523, 12.596404866602418]

# %%
plt.figure(figsize=(8,6))
plt.plot(levels, MAPE_BIM, label="Without defense",marker='o');
plt.plot(levels, MAPE_pca_BIM, label="With PCA",marker='o');
plt.plot(levels, MAPE_ae_BIM, label="With AE",marker='o');
plt.plot(levels, MAPE_GAN_BIM, label="With GAN",marker='o');
plt.xlabel("Pertubation Level",fontsize=15);
plt.ylabel("MAPE",fontsize=15);
plt.legend(prop={'size': 15})
plt.title("Basic Iterative Method",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Basic Iterative Method')

# %%
print(pert_level)
print(MAPE_BIM)
print(MAPE_pca_BIM)
print(MAPE_ae_BIM)
print(MAPE_GAN_BIM)
# Out:
# [0.0, 2.2702934984689875, 4.865583127167749, 7.36989058794435, 11.80520773920698, 21.1055368699207, 22.80712505786292, 20.565289005915083]
# [3.1708416030250284, 20.018225458449432, 34.808954908841, 47.85764916377174, 59.99485368996008, 71.42853909900911, 82.214942248743, 92.29973750315807]
# [10.847935421211098, 10.934006321654715, 11.474923638303713, 12.069091773914451, 13.131115201913559, 14.227892726161878, 15.231613852371067, 16.38182072206259]
# [7.955205484067947, 11.510172604693643, 15.932201194680609, 20.263321209712064, 24.415125948630088, 28.32369280712161, 32.26336865876147, 36.04652795415333]
# [6.10576831819024, 7.016460910637494, 7.94147040843991, 8.86883010560938, 9.799978058342736, 10.732120327762628, 11.664262597182523, 12.596404866602418]
